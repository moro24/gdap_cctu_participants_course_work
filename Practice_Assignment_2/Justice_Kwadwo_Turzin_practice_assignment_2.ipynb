# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## data loading and preprocessing
df1=pd.read_csv('car_price_prediction_project/Dataset/car_price_datatset.csv')
df1
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df1 = df1.copy(deep=True)

# %%
df1.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df1.tail(5)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
print("total number of rows",df1.shape[0], "total number of columns" , df1.shape[1])
# Out:
# total number of rows 11914 total number of columns 16

# %%
df1.info
# Out:
# <bound method DataFrame.info of           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df1.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
## finding the total count of unique values in each column

df1.nunique()
# Out:
# Make                   48
# Model                 915
# Year                   28
# Engine Fuel Type       10
# Engine HP             356
# Engine Cylinders        9
# Transmission Type       5
# Driven_Wheels           4
# Number of Doors         3
# Market Category        71
# Vehicle Size            3
# Vehicle Style          16
# highway MPG            59
# city mpg               69
# Popularity             48
# MSRP                 6049
# dtype: int64

# %%
## finding the unique instaces in each column
df1['Make'].unique
# Out:
# <bound method Series.unique of 0            BMW
# 1            BMW
# 2            BMW
# 3            BMW
# 4            BMW
#           ...
# 11909      Acura
# 11910      Acura
# 11911      Acura
# 11912      Acura
# 11913    Lincoln
# Name: Make, Length: 11914, dtype: object>

# %%
df1['Model'].unique
# Out:
# <bound method Series.unique of 0        1 Series M
# 1          1 Series
# 2          1 Series
# 3          1 Series
# 4          1 Series
#             ...
# 11909           ZDX
# 11910           ZDX
# 11911           ZDX
# 11912           ZDX
# 11913        Zephyr
# Name: Model, Length: 11914, dtype: object>

# %%
df1['Market Category'].unique
# Out:
# <bound method Series.unique of 0        Factory Tuner,Luxury,High-Performance
# 1                           Luxury,Performance
# 2                      Luxury,High-Performance
# 3                           Luxury,Performance
# 4                                       Luxury
#                          ...
# 11909               Crossover,Hatchback,Luxury
# 11910               Crossover,Hatchback,Luxury
# 11911               Crossover,Hatchback,Luxury
# 11912               Crossover,Hatchback,Luxury
# 11913                                   Luxury
# Name: Market Category, Length: 11914, dtype: object>

# %%
df1['MSRP'].unique
# Out:
# <bound method Series.unique of 0        46135
# 1        40650
# 2        36350
# 3        29450
# 4        34500
#          ...
# 11909    46120
# 11910    56670
# 11911    50620
# 11912    50920
# 11913    28995
# Name: MSRP, Length: 11914, dtype: int64>

# %%
df1['Transmission Type'].unique
# Out:
# <bound method Series.unique of 0           MANUAL
# 1           MANUAL
# 2           MANUAL
# 3           MANUAL
# 4           MANUAL
#            ...
# 11909    AUTOMATIC
# 11910    AUTOMATIC
# 11911    AUTOMATIC
# 11912    AUTOMATIC
# 11913    AUTOMATIC
# Name: Transmission Type, Length: 11914, dtype: object>

# %%
df1['Year'].unique
# Out:
# <bound method Series.unique of 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 11909    2012
# 11910    2012
# 11911    2012
# 11912    2013
# 11913    2006
# Name: Year, Length: 11914, dtype: int64>

# %%
df1['Engine Cylinders'].unique
# Out:
# <bound method Series.unique of 0        6.0
# 1        6.0
# 2        6.0
# 3        6.0
# 4        6.0
#         ...
# 11909    6.0
# 11910    6.0
# 11911    6.0
# 11912    6.0
# 11913    6.0
# Name: Engine Cylinders, Length: 11914, dtype: float64>

# %%
df1['Engine Fuel Type'].unique
# Out:
# <bound method Series.unique of 0           premium unleaded (required)
# 1           premium unleaded (required)
# 2           premium unleaded (required)
# 3           premium unleaded (required)
# 4           premium unleaded (required)
#                       ...
# 11909       premium unleaded (required)
# 11910       premium unleaded (required)
# 11911       premium unleaded (required)
# 11912    premium unleaded (recommended)
# 11913                  regular unleaded
# Name: Engine Fuel Type, Length: 11914, dtype: object>

# %%
df1['Engine HP'].unique
# Out:
# <bound method Series.unique of 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Engine HP, Length: 11914, dtype: float64>

# %%
df1['Vehicle Size'].unique
# Out:
# <bound method Series.unique of 0        Compact
# 1        Compact
# 2        Compact
# 3        Compact
# 4        Compact
#           ...
# 11909    Midsize
# 11910    Midsize
# 11911    Midsize
# 11912    Midsize
# 11913    Midsize
# Name: Vehicle Size, Length: 11914, dtype: object>

# %%
df1['Vehicle Style'].unique
# Out:
# <bound method Series.unique of 0                Coupe
# 1          Convertible
# 2                Coupe
# 3                Coupe
# 4          Convertible
#              ...
# 11909    4dr Hatchback
# 11910    4dr Hatchback
# 11911    4dr Hatchback
# 11912    4dr Hatchback
# 11913            Sedan
# Name: Vehicle Style, Length: 11914, dtype: object>

# %%
df1['Driven_Wheels'].unique
# Out:
# <bound method Series.unique of 0         rear wheel drive
# 1         rear wheel drive
# 2         rear wheel drive
# 3         rear wheel drive
# 4         rear wheel drive
#                ...
# 11909      all wheel drive
# 11910      all wheel drive
# 11911      all wheel drive
# 11912      all wheel drive
# 11913    front wheel drive
# Name: Driven_Wheels, Length: 11914, dtype: object>

# %%
df1['Popularity'].unique
# Out:
# <bound method Series.unique of 0        3916
# 1        3916
# 2        3916
# 3        3916
# 4        3916
#          ...
# 11909     204
# 11910     204
# 11911     204
# 11912     204
# 11913      61
# Name: Popularity, Length: 11914, dtype: int64>

# %%
df1['city mpg'].unique
# Out:
# <bound method Series.unique of 0        19
# 1        19
# 2        20
# 3        18
# 4        18
#          ..
# 11909    16
# 11910    16
# 11911    16
# 11912    16
# 11913    17
# Name: city mpg, Length: 11914, dtype: int64>

# %%
df1['Number of Doors'].unique
# Out:
# <bound method Series.unique of 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 11909    4.0
# 11910    4.0
# 11911    4.0
# 11912    4.0
# 11913    4.0
# Name: Number of Doors, Length: 11914, dtype: float64>

# %%
df1['highway MPG'].unique
# Out:
# <bound method Series.unique of 0        26
# 1        28
# 2        28
# 3        28
# 4        28
#          ..
# 11909    23
# 11910    23
# 11911    23
# 11912    23
# 11913    26
# Name: highway MPG, Length: 11914, dtype: int64>

# %% [markdown]
# ## data preprocesssing changing columns to lower cases

# %%
for each_item in df1.columns:
    print(each_item.lower())
# Out:
# make
# model
# year
# engine fuel type
# engine hp
# engine cylinders
# transmission type
# driven_wheels
# number of doors
# market category
# vehicle size
# vehicle style
# highway mpg
# city mpg
# popularity
# msrp

# %%
## performing EDA
df1.describe().round()
# Out:
#           Year  Engine HP  Engine Cylinders  Number of Doors  highway MPG  \
# count  11914.0    11845.0           11884.0          11908.0      11914.0
# mean    2010.0      249.0               6.0              3.0         27.0
# std        8.0      109.0               2.0              1.0          9.0
# min     1990.0       55.0               0.0              2.0         12.0
# 25%     2007.0      170.0               4.0              2.0         22.0
# 50%     2015.0      227.0               6.0              4.0         26.0
# 75%     2016.0      300.0               6.0              4.0         30.0
# max     2017.0     1001.0              16.0              4.0        354.0
#
#        city mpg  Popularity       MSRP
# count   11914.0     11914.0    11914.0
# mean       20.0      1555.0    40595.0
# std         9.0      1442.0    60109.0
# min         7.0         2.0     2000.0
# 25%        16.0       549.0    21000.0
# 50%        18.0      1385.0    29995.0
# ...

# %%
# select numerical only
numerical_cols=df1.select_dtypes(include=['int','float'])

# %%
numerical_cols
# Out:
#        Year  Engine HP  Engine Cylinders  Number of Doors  highway MPG  \
# 0      2011      335.0               6.0              2.0           26
# 1      2011      300.0               6.0              2.0           28
# 2      2011      300.0               6.0              2.0           28
# 3      2011      230.0               6.0              2.0           28
# 4      2011      230.0               6.0              2.0           28
# ...     ...        ...               ...              ...          ...
# 11909  2012      300.0               6.0              4.0           23
# 11910  2012      300.0               6.0              4.0           23
# 11911  2012      300.0               6.0              4.0           23
# 11912  2013      300.0               6.0              4.0           23
# 11913  2006      221.0               6.0              4.0           26
#
#        city mpg  Popularity   MSRP
# 0            19        3916  46135
# 1            19        3916  40650
# ...

# %%
correlation = numerical_cols.corr()

# %%
correlation
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.351794         -0.041479         0.263787
# Engine HP         0.351794   1.000000          0.779988        -0.102713
# Engine Cylinders -0.041479   0.779988          1.000000        -0.140088
# Number of Doors   0.263787  -0.102713         -0.140088         1.000000
# highway MPG       0.258240  -0.406563         -0.621606         0.118570
# city mpg          0.198171  -0.439371         -0.600776         0.120881
# Popularity        0.073049   0.037501          0.041145        -0.048272
# MSRP              0.227590   0.662008          0.531312        -0.126635
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.258240  0.198171    0.073049  0.227590
# Engine HP           -0.406563 -0.439371    0.037501  0.662008
# Engine Cylinders    -0.621606 -0.600776    0.041145  0.531312
# Number of Doors      0.118570  0.120881   -0.048272 -0.126635
# ...

# %% [markdown]
# ## target variable analysis

# %%
##Plot using matplotlib
plt.figure(figsize=(12, 6))
plt.hist(df1['Engine HP'], color= 'blue', bins= 5)
plt.title("Frequency Distribution  of Engine HPcolumn")
plt.xlabel("Engine HP")
plt.ylabel("Frequency")

plt.show()

# %%
## Plot using seaborn(sns)
plt.figure(figsize=(8, 4))
sns.histplot(df1['Engine Cylinders'], color='Orange', bins=10)
plt.title("Frequency Distribution of Engine Cylinders")
plt.xlabel("Engine Cylinders")
plt.ylabel("Frequency")

plt.show()
